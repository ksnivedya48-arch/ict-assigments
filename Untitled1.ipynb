# %% [markdown]
# <a href="https://colab.research.google.com/github/ksnivedya48-arch/ict-assigments/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter the price of first item:"))
b=int(input("enter the price of second item:"))
c=int(input("entter the quatity of 1st:"))
d=int(input("enter the quantiy of 2md:"))
print("totalbill amount is:",a*c+b*d)
# Out:
# enter the price of first item:45
# enter the price of second item:30
# entter the quatity of 1st:3
# enter the quantiy of 2md:2
# totalbill amount is: 195

# %%
c=float(input("enter the temprature in celisius:"))
f=(c*9/5)+32
print(f)
# Out:
# enter the temprature in celisius:30
# 86.0

# %%
s= float(input("enter the basic value"))
hra=0.20
da=0.10
hrasalary=s*hra
dasalary=s*da
print("net salary is",s+hrasalary+dasalary)
# Out:
# enter the basic value20000
# net salary is 26000.0

# %%
principal=float(input("enter the principal amount as (p):"))
rate_of_intrest=float(input("enter the rate of intrest as (r):"))
time=float(input("enter the time as (t):"))
simple_interest=(principal*rate_of_intrest*time)/100
print("the simple interest is:",simple_interest)
# Out:
# enter the principal amount as (p):10000
# enter the rate of intrest as (r):5
# enter the time as (t):2
# the simple interest is: 1000.0

# %%
total_minutes=int(input("enter the total minutes:"))
hours=total_minutes // 60
minutes=total_minutes  %60
print(f'{hours}hours and {minutes} minutes.')
# Out:
# enter the total minutes:130
# 2hours and 10 minutes.

# %%
weight_kg = float(input("Enter your weight in kilograms (kg): "))
height_m = float(input("Enter your height in meters (m): "))
bmi = weight_kg / (height_m ** 2)
print(f"BMI={bmi:.2f}")
# Out:
# Enter your weight in kilograms (kg): 60
# Enter your height in meters (m): 1.65
# BMI=22.04

# %%
original_price = float(input("Enter the original price of the item: "))
discount_percentage = 10
discount_amount = original_price * (discount_percentage / 100)
discounted_price = original_price - discount_amount
print(f"The original price was: ${original_price:.2f}")
print(f"Discount applied: {discount_percentage}%")
print(f"The discounted price is: ${discounted_price:.2f}")
# Out:
# Enter the original price of the item: 1200
# The original price was: $1200.00
# Discount applied: 10%
# The discounted price is: $1080.00

# %%
import math
a = float(input("Enter the length of side a: "))
b = float(input("Enter the length of side b: "))
c = float(input("Enter the length of side c: "))
if (a + b > c) and (a + c > b) and (b + c > a):
    s = (a + b + c) / 2
    area = math.sqrt(s * (s - a) * (s - b) * (s - c))


    print(f"The area of the triangle is: {area:.2f} square units")
# Out:
# Enter the length of side a: 5
# Enter the length of side b: 6
# Enter the length of side c: 7
# The area of the triangle is: 14.70 square units

# %%
RATE_PER_SQ_METER = 25
WINDOW_LENGTH = 1.5
WINDOW_WIDTH = 1.2
wall_length = float(input("Enter the length of the wall in meters: "))
wall_height = float(input("Enter the height of the wall in meters: "))
total_window_area = 2 * area_one_window
paintable_area = total_wall_area - total_window_area
if paintable_area < 0:
    paintable_area = 0
print(f"Area to be painted: {paintable_area:.2f} square meters")
print(f"Total painting cost: ₹{total_cost:.2f}")
# Out:
# Enter the length of the wall in meters: 12
# Enter the height of the wall in meters: 8
# Area to be painted: 92.40 square meters
# Total painting cost: ₹2310.00

# %%
RATE_PER_UNIT = 5.2
FIXED_CHARGE = 100
units_consumed = float(input("Enter the number of units consumed: "))
variable_charge = units_consumed * RATE_PER_UNIT
electricity_bill = variable_charge + FIXED_CHARGE
print(f"\nUnits Consumed: {units_consumed:.2f}")
print(f"electricity_bill: ₹{total_bill:.2f}")
# Out:
# Enter the number of units consumed: 250
#
# Units Consumed: 250.00
# electricity_bill: ₹1400.00
